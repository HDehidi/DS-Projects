# %% [markdown]
# # First steps with MongoDB and PyMongo
#
#
# *   Connection to Mongo
# *   Basic database, collection management
# *   CRUD  one document
# *   CRUD  many documents

# %% [markdown]
# # 1. Install PyMongo (if required)

# %%
# Instaling PyMongo, this is the interface to connect to MongoDB with Python
! python -m pip install pymongo==3.7.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo==3.7.2
#   Downloading pymongo-3.7.2-cp37-cp37m-manylinux1_x86_64.whl (406 kB)
#      |████████████████████████████████| 406 kB 5.6 MB/s
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.1.1
#     Uninstalling pymongo-4.1.1:
#       Successfully uninstalled pymongo-4.1.1
# Successfully installed pymongo-3.7.2

# %% [markdown]
# #2. Import PyMongo and establish connection
#
# To practice MongoDB, you can use a free service with limited storage to train or test your code.
#
# Here for the example, I use https://www.clever-cloud.com/en/
#
# Other services:
#
# https://studio3t.com/knowledge-base/articles/cheap-free-mongodb-hosting/

# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters 
# uri = 'mongodb://u1kkdrchfjim80tclysv:FeesC2ACNmI7be61RTst@brny4kjelauboxl-mongodb.services.clever-cloud.com:27017/brny4kjelauboxl'
uri = 'mongodb://uwczebggdchhvkj1uyzy:SdiO2szMNEM6THOqIaa9@beqbzkzp1knusxd-mongodb.services.clever-cloud.com:27017/beqbzkzp1knusxd'
# start client to connect to MongoDB server 
client = MongoClient( uri )

# %%
client.stats                                # .stats  show details about the client
# Out:
# Database(MongoClient(host=['beqbzkzp1knusxd-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'stats')

# %% [markdown]
# # 3. Basic Database management operations

# %%
# Show existing database names
client.list_database_names()
# Out:
# ['beqbzkzp1knusxd']

# %%
# Set database name to work with. If it doesn't exist, it will be created as soon as one document is added.
db = client.beqbzkzp1knusxd

# %%
# Delete a database
client.drop_database('beqbzkzp1knusxd')

# %% [markdown]
# #4. Basic Collection management operations

# %%
# Create a new collection. We can create the collection or leave to MongoDB to create it as soon as a document is generated.
db.create_collection('adressbook')       # Optional collection creation
# Out:
# Collection(Database(MongoClient(host=['beqbzkzp1knusxd-mongodb.services.clever-cloud.com:27017'], document_class=dict, tz_aware=False, connect=True), 'beqbzkzp1knusxd'), 'adressbook')

# %%
# Show Collections. Query returns a Cursor [ ] ,  list it to see the content
list (db.list_collections())
# empty list '[]' means that there are not collections in database
# Out:
# [{'idIndex': {'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'beqbzkzp1knusxd.adressbook',
#    'v': 2},
#   'info': {'readOnly': False,
#    'uuid': UUID('565d5a2b-5e93-4717-b718-1e8692c958c1')},
#   'name': 'adressbook',
#   'options': {},
#   'type': 'collection'}]

# %%
# Set the collection to work with
collection = db.adressbook
collection.insert_one({'name' : 'jordi'})     # Insert one item to create the collection
list (collection.find())                  # Show the existing collections
# Out:
# [{'_id': ObjectId('6291e1144c5577003be897d9'), 'name': 'jordi'}]

# %%
# Rename a collections
db.adressbook.rename('addressbook')
collection = db.addressbook                   # Set the collection to work with
list (db.list_collections())                  # Show the existing collections
# Out:
# [{'idIndex': {'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'beqbzkzp1knusxd.addressbook',
#    'v': 2},
#   'info': {'readOnly': False,
#    'uuid': UUID('565d5a2b-5e93-4717-b718-1e8692c958c1')},
#   'name': 'addressbook',
#   'options': {},
#   'type': 'collection'}]

# %%
# Delete collection
db.drop_collection('addressbook')
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1653727509, 65),
#   'signature': {'hash': b',\x7f\xe5w\xee\x89)\xafS\x10\x1a(\x93\xc3\xd5\x17\x86\xe3\xdf*',
#    'keyId': 7049308670210867201}},
#  'nIndexesWas': 1,
#  'ns': 'beqbzkzp1knusxd.addressbook',
#  'ok': 1.0,
#  'operationTime': Timestamp(1653727509, 65)}

# %% [markdown]
# # 5. Basic Collection operations

# %% [markdown]
# ##5.1 Query Operators - Create Read Update Delete  (one document)

# %% [markdown]
# ### 5.1.1 Create a document with:  insert_one()

# %% [markdown]
# To insert a document can be done using: insert_one and JavaScript notation  { 'attributeName1'  :  'content1', 'attributeName2'  :  'content2', ... }

# %%
#@title Contact

Name = "Jordi " #@param {type:"string"}
Age = 34 #@param {type:"slider", min:10, max:80, step:1}
Gender = "Male" #@param ["Male", "Female"]
Likes_Python = "Yes" #@param ["Yes", "No"]
if Likes_Python is "Yes":
  Likes_Python = True
else:
  Likes_Python = False


#@markdown Address
Street = "Torrent de l'Olla" #@param {type:"string"}
Number = 70 #@param {type:"integer"}
City = "Barcelona" #@param {type:"string"}
PostalCode = "08012" #@param {type:"string"}

# %%
data = {  'name' : Name ,                                    # String 
          'age' : Age,                                       # Integer
          'gender' : Gender,                                 # String 
          'likes_python' : Likes_Python,                     # Boolean
          'address': {
              'street' : Street,                             # String ( special character with escape \ )
              'number' : Number,                             # Integer
              'city' : City,                                 # String 
              'floor' : None,                                # Null 
              'postalcode' : PostalCode,                     # String containing a number
              },
          'favouriteFruits': ['banana','pineapple','orange'] # Array        
       }

insert_result = collection.insert_one( data)

# %%
insert_result.acknowledged    # Confirms that insert is successful
# Out:
# True

# %%
insert_result.inserted_id     # Shows the document ID
# Out:
# ObjectId('6291e1154c5577003be897da')

# %% [markdown]
# ###5.1.2 Read document with:  find()

# %% [markdown]
# To read a document can be done using: find and JavaScript notation  {  'attribute1 containing the key'  :  'key1 to find' }

# %%
list ( collection.find() )                                      # gets all data of collection
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 34,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
list ( collection.find( {'_id' : insert_result.inserted_id } ))  # Find the inserted document using the objectID
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 34,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
list ( collection.find( {'name' : Name } ))                     # find, can use one key or more
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 34,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
list ( collection.find( {'address.city' : City } ))             # find, can use one key or more
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 34,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
list ( collection.find().limit(1) )                             # gets a Limited set of documents
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 34,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
list ( collection.find().skip(1) )                              # gets all documents skipping first
# Out:
# []

# %% [markdown]
# ###5.1.3 Update a document with:  update_one()

# %%
## Update an existing document
update_result = collection.update_one( 
    {'name' : Name}, 
    {'$set' : { 'age' : 30 }} ) 

list (collection.find( {'name' : Name } ))

# Alternative : collection.find_one_and_update( {'name' : Name}, {'$set' : { 'age' : 30 }} )
# Out:
# [{'_id': ObjectId('6291e1154c5577003be897da'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalcode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 30,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'gender': 'Male',
#   'likes_python': True,
#   'name': 'Jordi '}]

# %%
update_result.raw_result
# Out:
# {'$clusterTime': {'clusterTime': Timestamp(1653727510, 56),
#   'signature': {'hash': b'h.\xff\xdb/\xdb\x08b\x94\x00\xaa\xd5\xb5Z\x0e\x03\xdfG\xce\xb2',
#    'keyId': 7049308670210867201}},
#  'electionId': ObjectId('7fffffff000000000000012b'),
#  'n': 1,
#  'nModified': 1,
#  'ok': 1.0,
#  'opTime': {'t': 299, 'ts': Timestamp(1653727510, 56)},
#  'operationTime': Timestamp(1653727510, 56),
#  'updatedExisting': True}

# %%
## Insert a new document with update, will avoid to crash during insert if document already exist
insert_result = collection.update_one( {'name' : 'Javi Gonzalez'}, {'$set' : { 'age' : 30 }}, upsert= True )
list (collection.find( {'name' : 'Javi Gonzalez'} ))
# Out:
# [{'_id': ObjectId('6291e11640c65683d0411550'),
#   'age': 30,
#   'name': 'Javi Gonzalez'}]

# %%
update_result.acknowledged
# Out:
# True

# %% [markdown]
# ###5.1.4 Delete a document with:  delete_one()

# %%
delete = collection.delete_one({'name': 'Javi Gonzalez'})

# %%
delete.deleted_count   # informs that 1 document has been deleted
# Out:
# 1

# %%
collection.delete_one({'name': Name})

# %% [markdown]
# ##5.2 Create Read Update Delete  (many document)

# %% [markdown]
# ###5.2.1 Create a document with:  insert_many()

# %% [markdown]
# To insert many documents can be done using: insert_many and JavaScript notation  { 'attributeDocument1'  :  'content1' } , { 'attributeDocument2'  :  'content2'},{ ... }

# %%
import datetime
collection.insert_many(  [                          # <---- start a list with [
##  Insert Document 1
  {
  'name': 'Jordi Gonzalez',
  'age': 25,
  'likes_python': True,
  'registered': datetime.datetime(2015, 2, 11, 4, 22, 39),
  'address': {
      'street': 'Torrent de l\'Olla',
      'number': 70,
      'floor': None,
      'city': 'Barcelona',
      'postalCode': '08012'
             },
  'height':  1.72,
  'favouriteFruits': ['banana','pineapple','orange']
  },

##  Insert Document 2
  {
  'name': 'Maria Smith',
  'age': 30,
  'likes_python': True,
  'registered': datetime.datetime(2016, 4, 23, 7, 34, 12),
  'address': {
      'street': 'Numancia',
                                                     ##  missing number
                                                     ##  missing floor
      'city': 'Barcelona',
      'postalCode': '08029'
             },
  'height':  1.56,
  'favouriteFruits': ['lemon','pineapple']
  }
  ]   )                                                   # <---- finalize the list ]

# %% [markdown]
# ###5.2.2 Read many documents with:  find()

# %% [markdown]
# To read a document can be done using: find and JavaScript notation  {  'attribute1 containing the key'  :  'key1 to find' }

# %%
list ( collection.find( {'$or': [ {'name': 'Jordi Gonzalez'},{'name': 'Maria Smith'} ]}))        # find
# Out:
# [{'_id': ObjectId('6291e1174c5577003be897db'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalCode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 25,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'height': 1.72,
#   'likes_python': True,
#   'name': 'Jordi Gonzalez',
#   'registered': datetime.datetime(2015, 2, 11, 4, 22, 39)},
#  {'_id': ObjectId('6291e1174c5577003be897dc'),
#   'address': {'city': 'Barcelona',
#    'postalCode': '08029',
#    'street': 'Numancia'},
#   'age': 30,
#   'favouriteFruits': ['lemon', 'pineapple'],
#   'height': 1.56,
#   'likes_python': True,
#   'name': 'Maria Smith',
#   'registered': datetime.datetime(2016, 4, 23, 7, 34, 12)}]

# %% [markdown]
# ###5.2.3 Update many documents with:  update_many()

# %%
collection.update_many( {'isActive': True }, {'$set' : { 'isActive': False }} )
list (collection.find( ))                                  # List all documents
# Out:
# [{'_id': ObjectId('6291e1174c5577003be897db'),
#   'address': {'city': 'Barcelona',
#    'floor': None,
#    'number': 70,
#    'postalCode': '08012',
#    'street': "Torrent de l'Olla"},
#   'age': 25,
#   'favouriteFruits': ['banana', 'pineapple', 'orange'],
#   'height': 1.72,
#   'likes_python': True,
#   'name': 'Jordi Gonzalez',
#   'registered': datetime.datetime(2015, 2, 11, 4, 22, 39)},
#  {'_id': ObjectId('6291e1174c5577003be897dc'),
#   'address': {'city': 'Barcelona',
#    'postalCode': '08029',
#    'street': 'Numancia'},
#   'age': 30,
#   'favouriteFruits': ['lemon', 'pineapple'],
#   'height': 1.56,
#   'likes_python': True,
#   'name': 'Maria Smith',
#   'registered': datetime.datetime(2016, 4, 23, 7, 34, 12)}]

# %% [markdown]
# ###5.2.4 Delete many documents with:  delete_many()

# %%
delete = collection.delete_many({'likes_python': True})    # deletes as many documents as the filter
list (collection.find( ))                                  # List all documents
# Out:
# []

# %%
delete.deleted_count   # items deleted
# Out:
# 2

# %% [markdown]
# # Assignment: Create your own collection
# 1- Create a collection with your name "name_surname"
#
# 2- Read california housing test dataset in sample_data folder in a pandas data frame.
#
# 3- Insert the pandas dataframe into your collection.
#
# 4- Retrieve the records from the collection having 'median_house_value' greater than 100000
#
# 5- Save those selected records to sample_data folder as a CSV file.

# %%
# Write your code here!
list (db.list_collections())
# Out:
# [{'idIndex': {'key': {'_id': 1},
#    'name': '_id_',
#    'ns': 'beqbzkzp1knusxd.addressbook',
#    'v': 2},
#   'info': {'readOnly': False,
#    'uuid': UUID('09d2ea7b-3b96-4039-99f1-7e0beab3204b')},
#   'name': 'addressbook',
#   'options': {},
#   'type': 'collection'}]

# %%
db.create_collection('Hamza_Dehidi')
collection = db.Hamza_Dehidi

# %%
import pandas as pd
df = pd.read_csv('/content/sample_data/california_housing_test.csv')
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
collection.insert_many(df.to_dict('records'))

# %%
list ( collection.find( { 'median_house_value': { '$gt': 100000 } } ))
# Out:
# [{'_id': ObjectId('6291e1184c5577003be897dd'),
#   'households': 606.0,
#   'housing_median_age': 27.0,
#   'latitude': 37.37,
#   'longitude': -122.05,
#   'median_house_value': 344700.0,
#   'median_income': 6.6085,
#   'population': 1537.0,
#   'total_bedrooms': 661.0,
#   'total_rooms': 3885.0},
#  {'_id': ObjectId('6291e1184c5577003be897de'),
#   'households': 277.0,
#   'housing_median_age': 43.0,
#   'latitude': 34.26,
#   'longitude': -118.3,
#   'median_house_value': 176500.0,
#   'median_income': 3.599,
#   'population': 809.0,
#   'total_bedrooms': 310.0,
#   'total_rooms': 1510.0},
#  {'_id': ObjectId('6291e1184c5577003be897df'),
#   'households': 495.0,
#   'housing_median_age': 27.0,
#   'latitude': 33.78,
#   'longitude': -117.81,
#   'median_house_value': 270500.0,
#   'median_income': 5.7934,
#   'population': 1484.0,
#   'total_bedrooms': 507.0,
#   'total_rooms': 3589.0},
#  {'_id': ObjectId('6291e1184c5577003be897e0'),
#   'households': 11.0,
#   'housing_median_age': 28.0,
#   'latitude': 33.82,
#   'longitude': -118.36,
#   'median_house_value': 330000.0,
#   'median_income': 6.1359,
#   'population': 49.0,
#   'total_bedrooms': 15.0,
#   'total_rooms': 67.0},
#  {'_id': ObjectId('6291e1184c5577003be897e4'),
#   'households': 441.0,
#   'housing_median_age': 19.0,
#   'latitude': 35.48,
#   'longitude': -120.65,
#   'median_house_value': 166900.0,
#   'median_income': 3.225,
#   'population': 1341.0,
#   'total_bedrooms': 471.0,
#   'total_rooms': 2310.0},
#  {'_id': ObjectId('6291e1184c5577003be897e5'),
#   'households': 599.0,
#   'housing_median_age': 15.0,
#   'latitude': 38.4,
#   'longitude': -122.84,
#   'median_house_value': 194400.0,
#   'median_income': 3.6696,
#   'population': 1446.0,
#   'total_bedrooms': 617.0,
#   'total_rooms': 3080.0},
#  {'_id': ObjectId('6291e1184c5577003be897e6'),
#   'households': 603.0,
#   'housing_median_age': 31.0,
#   'latitude': 34.08,
#   'longitude': -118.02,
#   'median_house_value': 164200.0,
#   'median_income': 2.3333,
#   'population': 2830.0,
#   'total_bedrooms': 632.0,
#   'total_rooms': 2402.0},
#  {'_id': ObjectId('6291e1184c5577003be897e7'),
#   'households': 261.0,
#   'housing_median_age': 45.0,
#   'latitude': 33.98,
#   'longitude': -118.24,
#   'median_house_value': 125000.0,
#   'median_income': 2.2054,
#   'population': 1288.0,
#   'total_bedrooms': 249.0,
#   'total_rooms': 972.0},
#  {'_id': ObjectId('6291e1184c5577003be897e9'),
#   'households': 170.0,
#   'housing_median_age': 36.0,
#   'latitude': 37.25,
#   'longitude': -121.93,
#   'median_house_value': 252600.0,
#   'median_income': 4.69,
#   'population': 535.0,
#   'total_bedrooms': 182.0,
#   'total_rooms': 1089.0},
#  {'_id': ObjectId('6291e1184c5577003be897ea'),
#   'households': 659.0,
#   'housing_median_age': 16.0,
#   'latitude': 32.97,
#   'longitude': -117.03,
#   'median_house_value': 231200.0,
#   'median_income': 4.5625,
#   'population': 1935.0,
#   'total_bedrooms': 694.0,
#   'total_rooms': 3936.0},
#  {'_id': ObjectId('6291e1184c5577003be897eb'),
#   'households': 331.0,
#   'housing_median_age': 27.0,
#   'latitude': 33.73,
#   'longitude': -117.97,
#   'median_house_value': 222500.0,
#   'median_income': 5.7121,
#   'population': 1217.0,
#   'total_bedrooms': 325.0,
#   'total_rooms': 2097.0},
#  {'_id': ObjectId('6291e1184c5577003be897ec'),
#   'households': 50.0,
#   'housing_median_age': 42.0,
#   'latitude': 33.81,
#   'longitude': -117.99,
#   'median_house_value': 153100.0,
#   'median_income': 2.2,
#   'population': 157.0,
#   'total_bedrooms': 40.0,
#   'total_rooms': 161.0},
#  {'_id': ObjectId('6291e1184c5577003be897ed'),
#   'households': 107.0,
#   'housing_median_age': 15.0,
#   'latitude': 37.53,
#   'longitude': -120.81,
#   'median_house_value': 181300.0,
#   'median_income': 1.875,
#   'population': 189.0,
#   'total_bedrooms': 123.0,
#   'total_rooms': 570.0},
#  {'_id': ObjectId('6291e1184c5577003be897ee'),
#   'households': 595.0,
#   'housing_median_age': 26.0,
#   'latitude': 38.69,
#   'longitude': -121.2,
#   'median_house_value': 137500.0,
#   'median_income': 2.7174,
#   'population': 1603.0,
#   'total_bedrooms': 607.0,
#   'total_rooms': 3077.0},
#  {'_id': ObjectId('6291e1184c5577003be897ef'),
#   'households': 199.0,
#   'housing_median_age': 26.0,
#   'latitude': 34.21,
#   'longitude': -118.88,
#   'median_house_value': 300000.0,
#   'median_income': 6.5851,
#   'population': 654.0,
#   'total_bedrooms': 196.0,
#   'total_rooms': 1590.0},
#  {'_id': ObjectId('6291e1184c5577003be897f0'),
#   'households': 1258.0,
#   'housing_median_age': 35.0,
#   'latitude': 38.01,
#   'longitude': -122.59,
#   'median_house_value': 414300.0,
#   'median_income': 6.1724,
#   'population': 3450.0,
#   'total_bedrooms': 1307.0,
#   'total_rooms': 8814.0},
#  {'_id': ObjectId('6291e1184c5577003be897f1'),
#   'households': 255.0,
#   'housing_median_age': 40.0,
#   'latitude': 37.75,
#   'longitude': -122.15,
#   'median_house_value': 126300.0,
#   'median_income': 3.8913,
#   'population': 849.0,
#   'total_bedrooms': 256.0,
#   'total_rooms': 1445.0},
#  {'_id': ObjectId('6291e1184c5577003be897f3'),
#   'households': 561.0,
#   'housing_median_age': 47.0,
#   'latitude': 34.07,
#   'longitude': -118.16,
#   'median_house_value': 241500.0,
#   'median_income': 3.8644,
#   'population': 1651.0,
#   'total_bedrooms': 543.0,
#   'total_rooms': 2994.0},
#  {'_id': ObjectId('6291e1184c5577003be897f4'),
#   'households': 480.0,
#   'housing_median_age': 45.0,
#   'latitude': 37.79,
#   'longitude': -122.2,
#   'median_house_value': 115400.0,
#   'median_income': 2.7788,
#   'population': 1410.0,
#   'total_bedrooms': 528.0,
#   'total_rooms': 2021.0},
#  {'_id': ObjectId('6291e1184c5577003be897f5'),
#   'households': 940.0,
#   'housing_median_age': 13.0,
#   'latitude': 33.28,
#   'longitude': -117.28,
#   'median_house_value': 150700.0,
#   'median_income': 3.8156,
#   'population': 4049.0,
#   'total_bedrooms': 1040.0,
#   'total_rooms': 6131.0},
#  {'_id': ObjectId('6291e1184c5577003be897f6'),
#   'households': 225.0,
#   'housing_median_age': 36.0,
#   'latitude': 34.16,
#   'longitude': -118.03,
#   'median_house_value': 484700.0,
#   'median_income': 7.1615,
#   'population': 667.0,
#   'total_bedrooms': 218.0,
#   'total_rooms': 1401.0},
#  {'_id': ObjectId('6291e1184c5577003be897f7'),
#   'households': 979.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.76,
#   'longitude': -122.42,
#   'median_house_value': 250000.0,
#   'median_income': 2.5403,
#   'population': 2259.0,
#   'total_bedrooms': 1030.0,
#   'total_rooms': 3587.0},
#  {'_id': ObjectId('6291e1184c5577003be897f8'),
#   'households': 402.0,
#   'housing_median_age': 32.0,
#   'latitude': 33.99,
#   'longitude': -118.39,
#   'median_house_value': 369200.0,
#   'median_income': 6.603,
#   'population': 1030.0,
#   'total_bedrooms': 418.0,
#   'total_rooms': 2612.0},
#  {'_id': ObjectId('6291e1184c5577003be897f9'),
#   'households': 1539.0,
#   'housing_median_age': 19.0,
#   'latitude': 34.07,
#   'longitude': -118.45,
#   'median_house_value': 350000.0,
#   'median_income': 1.583,
#   'population': 3751.0,
#   'total_bedrooms': 1609.0,
#   'total_rooms': 4845.0},
#  {'_id': ObjectId('6291e1184c5577003be897fa'),
#   'households': 901.0,
#   'housing_median_age': 30.0,
#   'latitude': 34.01,
#   'longitude': -118.48,
#   'median_house_value': 425000.0,
#   'median_income': 3.4852,
#   'population': 1561.0,
#   'total_bedrooms': 954.0,
#   'total_rooms': 3078.0},
#  {'_id': ObjectId('6291e1184c5577003be897fb'),
#   'households': 229.0,
#   'housing_median_age': 14.0,
#   'latitude': 36.33,
#   'longitude': -119.35,
#   'median_house_value': 105600.0,
#   'median_income': 3.1486,
#   'population': 568.0,
#   'total_bedrooms': 220.0,
#   'total_rooms': 1195.0},
#  {'_id': ObjectId('6291e1184c5577003be897fc'),
#   'households': 500.0,
#   'housing_median_age': 34.0,
#   'latitude': 33.91,
#   'longitude': -118.3,
#   'median_house_value': 172600.0,
#   'median_income': 2.6182,
#   'population': 1530.0,
#   'total_bedrooms': 493.0,
#   'total_rooms': 1617.0},
#  {'_id': ObjectId('6291e1184c5577003be897fd'),
#   'households': 619.0,
#   'housing_median_age': 17.0,
#   'latitude': 39.31,
#   'longitude': -121.13,
#   'median_house_value': 128900.0,
#   'median_income': 2.8102,
#   'population': 1693.0,
#   'total_bedrooms': 705.0,
#   'total_rooms': 3442.0},
#  {'_id': ObjectId('6291e1184c5577003be897fe'),
#   'households': 2651.0,
#   'housing_median_age': 5.0,
#   'latitude': 34.55,
#   'longitude': -118.08,
#   'median_house_value': 141800.0,
#   'median_income': 4.5237,
#   'population': 8152.0,
#   'total_bedrooms': 2971.0,
#   'total_rooms': 16181.0},
#  {'_id': ObjectId('6291e1184c5577003be897ff'),
#   'households': 169.0,
#   'housing_median_age': 38.0,
#   'latitude': 33.94,
#   'longitude': -118.32,
#   'median_house_value': 183800.0,
#   'median_income': 4.6389,
#   'population': 499.0,
#   'total_bedrooms': 170.0,
#   'total_rooms': 1067.0},
#  {'_id': ObjectId('6291e1184c5577003be89800'),
#   'households': 728.0,
#   'housing_median_age': 33.0,
#   'latitude': 34.0,
#   'longitude': -118.11,
#   'median_house_value': 178700.0,
#   'median_income': 2.625,
#   'population': 2650.0,
#   'total_bedrooms': 726.0,
#   'total_rooms': 2886.0},
#  {'_id': ObjectId('6291e1184c5577003be89801'),
#   'households': 419.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.97,
#   'longitude': -122.53,
#   'median_house_value': 270800.0,
#   'median_income': 2.5125,
#   'population': 700.0,
#   'total_bedrooms': 451.0,
#   'total_rooms': 1560.0},
#  {'_id': ObjectId('6291e1184c5577003be89802'),
#   'households': 277.0,
#   'housing_median_age': 34.0,
#   'latitude': 33.92,
#   'longitude': -118.02,
#   'median_house_value': 185300.0,
#   'median_income': 5.5238,
#   'population': 956.0,
#   'total_bedrooms': 251.0,
#   'total_rooms': 1478.0},
#  {'_id': ObjectId('6291e1184c5577003be89803'),
#   'households': 190.0,
#   'housing_median_age': 31.0,
#   'latitude': 33.93,
#   'longitude': -118.05,
#   'median_house_value': 141500.0,
#   'median_income': 3.6771,
#   'population': 883.0,
#   'total_bedrooms': 203.0,
#   'total_rooms': 894.0},
#  {'_id': ObjectId('6291e1184c5577003be89804'),
#   'households': 985.0,
#   'housing_median_age': 11.0,
#   'latitude': 34.23,
#   'longitude': -119.01,
#   'median_house_value': 232200.0,
#   'median_income': 4.693,
#   'population': 2760.0,
#   'total_bedrooms': 1035.0,
#   'total_rooms': 5785.0},
#  {'_id': ObjectId('6291e1184c5577003be89806'),
#   'households': 429.0,
#   'housing_median_age': 16.0,
#   'latitude': 32.77,
#   'longitude': -116.92,
#   'median_house_value': 275000.0,
#   'median_income': 6.6783,
#   'population': 1269.0,
#   'total_bedrooms': 406.0,
#   'total_rooms': 2770.0},
#  {'_id': ObjectId('6291e1184c5577003be89807'),
#   'households': 226.0,
#   'housing_median_age': 37.0,
#   'latitude': 34.15,
#   'longitude': -118.06,
#   'median_house_value': 500001.0,
#   'median_income': 15.0001,
#   'population': 697.0,
#   'total_bedrooms': 226.0,
#   'total_rooms': 1980.0},
#  {'_id': ObjectId('6291e1184c5577003be89809'),
#   'households': 294.0,
#   'housing_median_age': 48.0,
#   'latitude': 34.13,
#   'longitude': -118.23,
#   'median_house_value': 214800.0,
#   'median_income': 4.2891,
#   'population': 835.0,
#   'total_bedrooms': 286.0,
#   'total_rooms': 1308.0},
#  {'_id': ObjectId('6291e1184c5577003be8980a'),
#   'households': 1672.0,
#   'housing_median_age': 4.0,
#   'latitude': 33.17,
#   'longitude': -117.24,
#   'median_house_value': 237500.0,
#   'median_income': 4.2826,
#   'population': 3925.0,
#   'total_bedrooms': 1874.0,
#   'total_rooms': 9998.0},
#  {'_id': ObjectId('6291e1184c5577003be8980b'),
#   'households': 242.0,
#   'housing_median_age': 24.0,
#   'latitude': 37.44,
#   'longitude': -121.91,
#   'median_house_value': 212500.0,
#   'median_income': 5.0808,
#   'population': 799.0,
#   'total_bedrooms': 251.0,
#   'total_rooms': 1212.0},
#  {'_id': ObjectId('6291e1184c5577003be8980c'),
#   'households': 329.0,
#   'housing_median_age': 47.0,
#   'latitude': 33.94,
#   'longitude': -118.29,
#   'median_house_value': 105700.0,
#   'median_income': 2.5398,
#   'population': 1003.0,
#   'total_bedrooms': 338.0,
#   'total_rooms': 1782.0},
#  {'_id': ObjectId('6291e1184c5577003be8980d'),
#   'households': 350.0,
#   'housing_median_age': 6.0,
#   'latitude': 38.0,
#   'longitude': -121.35,
#   'median_house_value': 123800.0,
#   'median_income': 3.4231,
#   'population': 732.0,
#   'total_bedrooms': 369.0,
#   'total_rooms': 1649.0},
#  {'_id': ObjectId('6291e1184c5577003be8980e'),
#   'households': 1593.0,
#   'housing_median_age': 19.0,
#   'latitude': 33.78,
#   'longitude': -117.99,
#   'median_house_value': 173900.0,
#   'median_income': 3.1049,
#   'population': 3554.0,
#   'total_bedrooms': 1698.0,
#   'total_rooms': 7399.0},
#  {'_id': ObjectId('6291e1184c5577003be8980f'),
#   'households': 1780.0,
#   'housing_median_age': 14.0,
#   'latitude': 37.7,
#   'longitude': -120.99,
#   'median_house_value': 160900.0,
#   'median_income': 3.5877,
#   'population': 4356.0,
#   'total_bedrooms': 1887.0,
#   'total_rooms': 9849.0},
#  {'_id': ObjectId('6291e1184c5577003be89811'),
#   'households': 464.0,
#   'housing_median_age': 39.0,
#   'latitude': 37.8,
#   'longitude': -122.21,
#   'median_house_value': 156500.0,
#   'median_income': 3.0682,
#   'population': 1109.0,
#   'total_bedrooms': 500.0,
#   'total_rooms': 2003.0},
#  {'_id': ObjectId('6291e1184c5577003be89812'),
#   'households': 366.0,
#   'housing_median_age': 26.0,
#   'latitude': 33.8,
#   'longitude': -118.17,
#   'median_house_value': 187500.0,
#   'median_income': 3.5313,
#   'population': 883.0,
#   'total_bedrooms': 380.0,
#   'total_rooms': 1589.0},
#  {'_id': ObjectId('6291e1184c5577003be89813'),
#   'households': 335.0,
#   'housing_median_age': 39.0,
#   'latitude': 34.09,
#   'longitude': -117.9,
#   'median_house_value': 191800.0,
#   'median_income': 4.3409,
#   'population': 892.0,
#   'total_bedrooms': 333.0,
#   'total_rooms': 1726.0},
#  {'_id': ObjectId('6291e1184c5577003be89814'),
#   'households': 229.0,
#   'housing_median_age': 36.0,
#   'latitude': 33.93,
#   'longitude': -117.99,
#   'median_house_value': 175800.0,
#   'median_income': 4.8523,
#   'population': 779.0,
#   'total_bedrooms': 233.0,
#   'total_rooms': 1287.0},
#  {'_id': ObjectId('6291e1184c5577003be89816'),
#   'households': 468.0,
#   'housing_median_age': 26.0,
#   'latitude': 34.26,
#   'longitude': -118.77,
#   'median_house_value': 196900.0,
#   'median_income': 5.6385,
#   'population': 1825.0,
#   'total_bedrooms': 468.0,
#   'total_rooms': 3038.0},
#  {'_id': ObjectId('6291e1184c5577003be89817'),
#   'households': 282.0,
#   'housing_median_age': 44.0,
#   'latitude': 37.33,
#   'longitude': -121.93,
#   'median_house_value': 292200.0,
#   'median_income': 3.575,
#   'population': 676.0,
#   'total_bedrooms': 291.0,
#   'total_rooms': 1449.0},
#  {'_id': ObjectId('6291e1184c5577003be89818'),
#   'households': 586.0,
#   'housing_median_age': 16.0,
#   'latitude': 37.25,
#   'longitude': -121.82,
#   'median_house_value': 194300.0,
#   'median_income': 3.9461,
#   'population': 1969.0,
#   'total_bedrooms': 600.0,
#   'total_rooms': 2650.0},
#  {'_id': ObjectId('6291e1184c5577003be89819'),
#   'households': 139.0,
#   'housing_median_age': 36.0,
#   'latitude': 37.56,
#   'longitude': -122.29,
#   'median_house_value': 289400.0,
#   'median_income': 5.8221,
#   'population': 445.0,
#   'total_bedrooms': 140.0,
#   'total_rooms': 805.0},
#  {'_id': ObjectId('6291e1184c5577003be8981a'),
#   'households': 285.0,
#   'housing_median_age': 18.0,
#   'latitude': 37.23,
#   'longitude': -121.78,
#   'median_house_value': 229100.0,
#   'median_income': 5.898,
#   'population': 1055.0,
#   'total_bedrooms': 317.0,
#   'total_rooms': 1747.0},
#  {'_id': ObjectId('6291e1184c5577003be8981b'),
#   'households': 307.0,
#   'housing_median_age': 35.0,
#   'latitude': 34.0,
#   'longitude': -118.41,
#   'median_house_value': 265500.0,
#   'median_income': 2.7153,
#   'population': 1026.0,
#   'total_bedrooms': 305.0,
#   'total_rooms': 1062.0},
#  {'_id': ObjectId('6291e1184c5577003be8981d'),
#   'households': 404.0,
#   'housing_median_age': 26.0,
#   'latitude': 33.92,
#   'longitude': -118.0,
#   'median_house_value': 289600.0,
#   'median_income': 6.1273,
#   'population': 1204.0,
#   'total_bedrooms': 399.0,
#   'total_rooms': 2830.0},
#  {'_id': ObjectId('6291e1184c5577003be8981e'),
#   'households': 729.0,
#   'housing_median_age': 38.0,
#   'latitude': 32.73,
#   'longitude': -117.22,
#   'median_house_value': 291400.0,
#   'median_income': 3.8409,
#   'population': 1640.0,
#   'total_bedrooms': 768.0,
#   'total_rooms': 3966.0},
#  {'_id': ObjectId('6291e1184c5577003be8981f'),
#   'households': 1123.0,
#   'housing_median_age': 19.0,
#   'latitude': 37.69,
#   'longitude': -121.08,
#   'median_house_value': 129300.0,
#   'median_income': 3.2246,
#   'population': 3559.0,
#   'total_bedrooms': 1212.0,
#   'total_rooms': 6473.0},
#  {'_id': ObjectId('6291e1184c5577003be89820'),
#   'households': 228.0,
#   'housing_median_age': 12.0,
#   'latitude': 33.92,
#   'longitude': -117.53,
#   'median_house_value': 233500.0,
#   'median_income': 6.1561,
#   'population': 728.0,
#   'total_bedrooms': 319.0,
#   'total_rooms': 2290.0},
#  {'_id': ObjectId('6291e1184c5577003be89821'),
#   'households': 702.0,
#   'housing_median_age': 18.0,
#   'latitude': 34.08,
#   'longitude': -117.46,
#   'median_house_value': 120700.0,
#   'median_income': 3.6602,
#   'population': 2767.0,
#   'total_bedrooms': 750.0,
#   'total_rooms': 3830.0},
#  {'_id': ObjectId('6291e1184c5577003be89822'),
#   'households': 378.0,
#   'housing_median_age': 35.0,
#   'latitude': 33.86,
#   'longitude': -117.97,
#   'median_house_value': 174300.0,
#   'median_income': 3.5855,
#   'population': 1265.0,
#   'total_bedrooms': 367.0,
#   'total_rooms': 1691.0},
#  {'_id': ObjectId('6291e1184c5577003be89823'),
#   'households': 387.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.33,
#   'longitude': -121.92,
#   'median_house_value': 299500.0,
#   'median_income': 5.2831,
#   'population': 930.0,
#   'total_bedrooms': 382.0,
#   'total_rooms': 2125.0},
#  {'_id': ObjectId('6291e1184c5577003be89824'),
#   'households': 515.0,
#   'housing_median_age': 44.0,
#   'latitude': 34.04,
#   'longitude': -118.2,
#   'median_house_value': 125000.0,
#   'median_income': 1.6888,
#   'population': 1998.0,
#   'total_bedrooms': 544.0,
#   'total_rooms': 1582.0},
#  {'_id': ObjectId('6291e1184c5577003be89825'),
#   'households': 404.0,
#   'housing_median_age': 22.0,
#   'latitude': 33.8,
#   'longitude': -118.06,
#   'median_house_value': 212500.0,
#   'median_income': 4.1379,
#   'population': 1015.0,
#   'total_bedrooms': 442.0,
#   'total_rooms': 1892.0},
#  {'_id': ObjectId('6291e1184c5577003be89826'),
#   'households': 384.0,
#   'housing_median_age': 34.0,
#   'latitude': 37.36,
#   'longitude': -122.05,
#   'median_house_value': 316900.0,
#   'median_income': 4.1369,
#   'population': 1017.0,
#   'total_bedrooms': 419.0,
#   'total_rooms': 2400.0},
#  {'_id': ObjectId('6291e1184c5577003be89827'),
#   'households': 274.0,
#   'housing_median_age': 24.0,
#   'latitude': 39.5,
#   'longitude': -123.79,
#   'median_house_value': 157300.0,
#   'median_income': 2.325,
#   'population': 588.0,
#   'total_bedrooms': 291.0,
#   'total_rooms': 1421.0},
#  {'_id': ObjectId('6291e1184c5577003be89828'),
#   'households': 234.0,
#   'housing_median_age': 44.0,
#   'latitude': 37.49,
#   'longitude': -120.79,
#   'median_house_value': 160700.0,
#   'median_income': 3.4167,
#   'population': 687.0,
#   'total_bedrooms': 225.0,
#   'total_rooms': 1186.0},
#  {'_id': ObjectId('6291e1184c5577003be89829'),
#   'households': 606.0,
#   'housing_median_age': 47.0,
#   'latitude': 37.35,
#   'longitude': -121.89,
#   'median_house_value': 183100.0,
#   'median_income': 3.2599,
#   'population': 2229.0,
#   'total_bedrooms': 631.0,
#   'total_rooms': 2879.0},
#  {'_id': ObjectId('6291e1184c5577003be8982a'),
#   'households': 679.0,
#   'housing_median_age': 29.0,
#   'latitude': 34.2,
#   'longitude': -118.43,
#   'median_house_value': 238100.0,
#   'median_income': 3.1118,
#   'population': 1942.0,
#   'total_bedrooms': 694.0,
#   'total_rooms': 3051.0},
#  {'_id': ObjectId('6291e1184c5577003be8982b'),
#   'households': 834.0,
#   'housing_median_age': 18.0,
#   'latitude': 34.17,
#   'longitude': -118.75,
#   'median_house_value': 325900.0,
#   'median_income': 6.8075,
#   'population': 2703.0,
#   'total_bedrooms': 858.0,
#   'total_rooms': 6217.0},
#  {'_id': ObjectId('6291e1184c5577003be8982c'),
#   'households': 957.0,
#   'housing_median_age': 22.0,
#   'latitude': 37.99,
#   'longitude': -122.47,
#   'median_house_value': 439200.0,
#   'median_income': 7.494,
#   'population': 2468.0,
#   'total_bedrooms': 1002.0,
#   'total_rooms': 7274.0},
#  {'_id': ObjectId('6291e1184c5577003be8982d'),
#   'households': 147.0,
#   'housing_median_age': 46.0,
#   'latitude': 37.4,
#   'longitude': -120.69,
#   'median_house_value': 137500.0,
#   'median_income': 3.5167,
#   'population': 496.0,
#   'total_bedrooms': 130.0,
#   'total_rooms': 860.0},
#  {'_id': ObjectId('6291e1184c5577003be8982e'),
#   'households': 375.0,
#   'housing_median_age': 44.0,
#   'latitude': 34.05,
#   'longitude': -118.28,
#   'median_house_value': 212500.0,
#   'median_income': 1.4801,
#   'population': 1805.0,
#   'total_bedrooms': 384.0,
#   'total_rooms': 968.0},
#  {'_id': ObjectId('6291e1184c5577003be8982f'),
#   'households': 351.0,
#   'housing_median_age': 35.0,
#   'latitude': 34.25,
#   'longitude': -118.44,
#   'median_house_value': 176000.0,
#   'median_income': 3.7,
#   'population': 1481.0,
#   'total_bedrooms': 324.0,
#   'total_rooms': 1583.0},
#  {'_id': ObjectId('6291e1184c5577003be89830'),
#   'households': 1377.0,
#   'housing_median_age': 21.0,
#   'latitude': 38.26,
#   'longitude': -122.05,
#   'median_house_value': 126300.0,
#   'median_income': 3.0912,
#   'population': 3927.0,
#   'total_bedrooms': 1416.0,
#   'total_rooms': 7195.0},
#  {'_id': ObjectId('6291e1184c5577003be89831'),
#   'households': 467.0,
#   'housing_median_age': 18.0,
#   'latitude': 37.35,
#   'longitude': -121.99,
#   'median_house_value': 238900.0,
#   'median_income': 4.3971,
#   'population': 972.0,
#   'total_bedrooms': 509.0,
#   'total_rooms': 1712.0},
#  {'_id': ObjectId('6291e1184c5577003be89832'),
#   'households': 558.0,
#   'housing_median_age': 28.0,
#   'latitude': 37.68,
#   'longitude': -121.02,
#   'median_house_value': 106400.0,
#   'median_income': 3.5489,
#   'population': 1608.0,
#   'total_bedrooms': 560.0,
#   'total_rooms': 2875.0},
#  {'_id': ObjectId('6291e1184c5577003be89834'),
#   'households': 581.0,
#   'housing_median_age': 28.0,
#   'latitude': 34.08,
#   'longitude': -118.02,
#   'median_house_value': 175900.0,
#   'median_income': 2.6071,
#   'population': 2452.0,
#   'total_bedrooms': 631.0,
#   'total_rooms': 2769.0},
#  {'_id': ObjectId('6291e1184c5577003be89836'),
#   'households': 335.0,
#   'housing_median_age': 44.0,
#   'latitude': 37.62,
#   'longitude': -122.4,
#   'median_house_value': 224200.0,
#   'median_income': 4.0238,
#   'population': 1064.0,
#   'total_bedrooms': 362.0,
#   'total_rooms': 1619.0},
#  {'_id': ObjectId('6291e1184c5577003be89837'),
#   'households': 321.0,
#   'housing_median_age': 24.0,
#   'latitude': 34.15,
#   'longitude': -118.13,
#   'median_house_value': 141700.0,
#   'median_income': 2.8125,
#   'population': 579.0,
#   'total_bedrooms': 341.0,
#   'total_rooms': 1125.0},
#  {'_id': ObjectId('6291e1184c5577003be89838'),
#   'households': 173.0,
#   'housing_median_age': 32.0,
#   'latitude': 37.98,
#   'longitude': -122.0,
#   'median_house_value': 226900.0,
#   'median_income': 5.1118,
#   'population': 436.0,
#   'total_bedrooms': 169.0,
#   'total_rooms': 1013.0},
#  {'_id': ObjectId('6291e1184c5577003be89839'),
#   'households': 275.0,
#   'housing_median_age': 36.0,
#   'latitude': 34.25,
#   'longitude': -118.45,
#   'median_house_value': 204600.0,
#   'median_income': 4.3839,
#   'population': 808.0,
#   'total_bedrooms': 270.0,
#   'total_rooms': 1453.0},
#  {'_id': ObjectId('6291e1184c5577003be8983a'),
#   'households': 850.0,
#   'housing_median_age': 4.0,
#   'latitude': 33.87,
#   'longitude': -117.5,
#   'median_house_value': 239800.0,
#   'median_income': 5.0493,
#   'population': 2866.0,
#   'total_bedrooms': 1017.0,
#   'total_rooms': 6755.0},
#  {'_id': ObjectId('6291e1184c5577003be8983b'),
#   'households': 479.0,
#   'housing_median_age': 50.0,
#   'latitude': 37.84,
#   'longitude': -122.22,
#   'median_house_value': 295200.0,
#   'median_income': 7.5,
#   'population': 1031.0,
#   'total_bedrooms': 473.0,
#   'total_rooms': 2935.0},
#  {'_id': ObjectId('6291e1184c5577003be8983e'),
#   'households': 287.0,
#   'housing_median_age': 16.0,
#   'latitude': 38.42,
#   'longitude': -120.97,
#   'median_house_value': 121900.0,
#   'median_income': 4.3029,
#   'population': 4930.0,
#   'total_bedrooms': 322.0,
#   'total_rooms': 1748.0},
#  {'_id': ObjectId('6291e1184c5577003be8983f'),
#   'households': 519.0,
#   'housing_median_age': 20.0,
#   'latitude': 38.87,
#   'longitude': -121.19,
#   'median_house_value': 209400.0,
#   'median_income': 6.0,
#   'population': 1405.0,
#   'total_bedrooms': 500.0,
#   'total_rooms': 3118.0},
#  {'_id': ObjectId('6291e1184c5577003be89840'),
#   'households': 317.0,
#   'housing_median_age': 52.0,
#   'latitude': 33.77,
#   'longitude': -118.2,
#   'median_house_value': 200000.0,
#   'median_income': 2.2344,
#   'population': 1089.0,
#   'total_bedrooms': 457.0,
#   'total_rooms': 1375.0},
#  {'_id': ObjectId('6291e1184c5577003be89841'),
#   'households': 416.0,
#   'housing_median_age': 49.0,
#   'latitude': 34.02,
#   'longitude': -118.3,
#   'median_house_value': 116800.0,
#   'median_income': 1.85,
#   'population': 1522.0,
#   'total_bedrooms': 483.0,
#   'total_rooms': 2120.0},
#  {'_id': ObjectId('6291e1184c5577003be89842'),
#   'households': 1231.0,
#   'housing_median_age': 43.0,
#   'latitude': 37.79,
#   'longitude': -122.23,
#   'median_house_value': 112800.0,
#   'median_income': 2.1917,
#   'population': 4367.0,
#   'total_bedrooms': 1344.0,
#   'total_rooms': 5963.0},
#  {'_id': ObjectId('6291e1184c5577003be89843'),
#   'households': 456.0,
#   'housing_median_age': 31.0,
#   'latitude': 38.62,
#   'longitude': -121.31,
#   'median_house_value': 240000.0,
#   'median_income': 6.244,
#   'population': 1121.0,
#   'total_bedrooms': 430.0,
#   'total_rooms': 3114.0},
#  {'_id': ObjectId('6291e1184c5577003be89844'),
#   'households': 496.0,
#   'housing_median_age': 35.0,
#   'latitude': 32.8,
#   'longitude': -117.25,
#   'median_house_value': 275000.0,
#   'median_income': 4.2296,
#   'population': 1005.0,
#   'total_bedrooms': 506.0,
#   'total_rooms': 2281.0},
#  {'_id': ObjectId('6291e1184c5577003be89845'),
#   'households': 464.0,
#   'housing_median_age': 36.0,
#   'latitude': 33.99,
#   'longitude': -118.26,
#   'median_house_value': 103500.0,
#   'median_income': 1.6901,
#   'population': 1807.0,
#   'total_bedrooms': 505.0,
#   'total_rooms': 2016.0},
#  {'_id': ObjectId('6291e1184c5577003be89847'),
#   'households': 569.0,
#   'housing_median_age': 30.0,
#   'latitude': 38.52,
#   'longitude': -121.51,
#   'median_house_value': 181400.0,
#   'median_income': 4.0972,
#   'population': 1167.0,
#   'total_bedrooms': 588.0,
#   'total_rooms': 3236.0},
#  {'_id': ObjectId('6291e1184c5577003be89848'),
#   'households': 364.0,
#   'housing_median_age': 6.0,
#   'latitude': 34.27,
#   'longitude': -119.18,
#   'median_house_value': 279500.0,
#   'median_income': 5.215,
#   'population': 910.0,
#   'total_bedrooms': 386.0,
#   'total_rooms': 2307.0},
#  {'_id': ObjectId('6291e1184c5577003be89849'),
#   'households': 417.0,
#   'housing_median_age': 30.0,
#   'latitude': 33.77,
#   'longitude': -118.18,
#   'median_house_value': 159400.0,
#   'median_income': 2.6371,
#   'population': 720.0,
#   'total_bedrooms': 439.0,
#   'total_rooms': 1418.0},
#  {'_id': ObjectId('6291e1184c5577003be8984a'),
#   'households': 301.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.74,
#   'longitude': -122.43,
#   'median_house_value': 300900.0,
#   'median_income': 5.3292,
#   'population': 724.0,
#   'total_bedrooms': 314.0,
#   'total_rooms': 1514.0},
#  {'_id': ObjectId('6291e1184c5577003be8984b'),
#   'households': 273.0,
#   'housing_median_age': 24.0,
#   'latitude': 33.91,
#   'longitude': -117.93,
#   'median_house_value': 364600.0,
#   'median_income': 5.2017,
#   'population': 676.0,
#   'total_bedrooms': 297.0,
#   'total_rooms': 1698.0},
#  {'_id': ObjectId('6291e1184c5577003be8984d'),
#   'households': 443.0,
#   'housing_median_age': 27.0,
#   'latitude': 33.63,
#   'longitude': -117.95,
#   'median_house_value': 358800.0,
#   'median_income': 5.8777,
#   'population': 1082.0,
#   'total_bedrooms': 481.0,
#   'total_rooms': 2489.0},
#  {'_id': ObjectId('6291e1184c5577003be8984e'),
#   'households': 294.0,
#   'housing_median_age': 36.0,
#   'latitude': 34.1,
#   'longitude': -118.05,
#   'median_house_value': 272600.0,
#   'median_income': 4.7931,
#   'population': 889.0,
#   'total_bedrooms': 318.0,
#   'total_rooms': 1606.0},
#  {'_id': ObjectId('6291e1184c5577003be8984f'),
#   'households': 414.0,
#   'housing_median_age': 19.0,
#   'latitude': 32.81,
#   'longitude': -116.97,
#   'median_house_value': 125000.0,
#   'median_income': 2.1422,
#   'population': 844.0,
#   'total_bedrooms': 471.0,
#   'total_rooms': 1573.0},
#  {'_id': ObjectId('6291e1184c5577003be89850'),
#   'households': 81.0,
#   'housing_median_age': 42.0,
#   'latitude': 34.17,
#   'longitude': -118.85,
#   'median_house_value': 318800.0,
#   'median_income': 4.5625,
#   'population': 220.0,
#   'total_bedrooms': 96.0,
#   'total_rooms': 564.0},
#  {'_id': ObjectId('6291e1184c5577003be89851'),
#   'households': 586.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.63,
#   'longitude': -117.73,
#   'median_house_value': 161800.0,
#   'median_income': 5.5137,
#   'population': 1382.0,
#   'total_bedrooms': 592.0,
#   'total_rooms': 2874.0},
#  {'_id': ObjectId('6291e1184c5577003be89852'),
#   'households': 236.0,
#   'housing_median_age': 30.0,
#   'latitude': 37.34,
#   'longitude': -122.07,
#   'median_house_value': 500001.0,
#   'median_income': 10.1007,
#   'population': 631.0,
#   'total_bedrooms': 238.0,
#   'total_rooms': 1851.0},
#  {'_id': ObjectId('6291e1184c5577003be89853'),
#   'households': 425.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.02,
#   'longitude': -117.18,
#   'median_house_value': 500001.0,
#   'median_income': 13.6623,
#   'population': 1364.0,
#   'total_bedrooms': 453.0,
#   'total_rooms': 3540.0},
#  {'_id': ObjectId('6291e1184c5577003be89854'),
#   'households': 73.0,
#   'housing_median_age': 38.0,
#   'latitude': 34.0,
#   'longitude': -118.41,
#   'median_house_value': 271400.0,
#   'median_income': 2.55,
#   'population': 268.0,
#   'total_bedrooms': 70.0,
#   'total_rooms': 324.0},
#  {'_id': ObjectId('6291e1184c5577003be89855'),
#   'households': 1007.0,
#   'housing_median_age': 20.0,
#   'latitude': 37.3,
#   'longitude': -121.96,
#   'median_house_value': 227300.0,
#   'median_income': 4.3081,
#   'population': 2334.0,
#   'total_bedrooms': 1006.0,
#   'total_rooms': 4228.0},
#  {'_id': ObjectId('6291e1184c5577003be89856'),
#   'households': 536.0,
#   'housing_median_age': 34.0,
#   'latitude': 38.55,
#   'longitude': -121.74,
#   'median_house_value': 148500.0,
#   'median_income': 1.6435,
#   'population': 1300.0,
#   'total_bedrooms': 579.0,
#   'total_rooms': 2299.0},
#  {'_id': ObjectId('6291e1184c5577003be89857'),
#   'households': 930.0,
#   'housing_median_age': 28.0,
#   'latitude': 33.92,
#   'longitude': -118.21,
#   'median_house_value': 131900.0,
#   'median_income': 1.9026,
#   'population': 4551.0,
#   'total_bedrooms': 1003.0,
#   'total_rooms': 2949.0},
#  {'_id': ObjectId('6291e1184c5577003be89858'),
#   'households': 759.0,
#   'housing_median_age': 29.0,
#   'latitude': 36.61,
#   'longitude': -121.9,
#   'median_house_value': 217100.0,
#   'median_income': 2.9309,
#   'population': 1574.0,
#   'total_bedrooms': 827.0,
#   'total_rooms': 3412.0},
#  {'_id': ObjectId('6291e1184c5577003be89859'),
#   'households': 484.0,
#   'housing_median_age': 17.0,
#   'latitude': 33.84,
#   'longitude': -117.81,
#   'median_house_value': 460100.0,
#   'median_income': 10.5981,
#   'population': 1605.0,
#   'total_bedrooms': 515.0,
#   'total_rooms': 4343.0},
#  {'_id': ObjectId('6291e1184c5577003be8985a'),
#   'households': 377.0,
#   'housing_median_age': 42.0,
#   'latitude': 33.93,
#   'longitude': -118.19,
#   'median_house_value': 146400.0,
#   'median_income': 3.1912,
#   'population': 1614.0,
#   'total_bedrooms': 391.0,
#   'total_rooms': 1829.0},
#  {'_id': ObjectId('6291e1184c5577003be8985c'),
#   'households': 366.0,
#   'housing_median_age': 25.0,
#   'latitude': 37.96,
#   'longitude': -122.02,
#   'median_house_value': 305100.0,
#   'median_income': 6.6727,
#   'population': 935.0,
#   'total_bedrooms': 368.0,
#   'total_rooms': 2615.0},
#  {'_id': ObjectId('6291e1184c5577003be8985d'),
#   'households': 596.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.79,
#   'longitude': -122.47,
#   'median_house_value': 500001.0,
#   'median_income': 4.75,
#   'population': 1380.0,
#   'total_bedrooms': 623.0,
#   'total_rooms': 2844.0},
#  {'_id': ObjectId('6291e1184c5577003be8985e'),
#   'households': 320.0,
#   'housing_median_age': 25.0,
#   'latitude': 34.03,
#   'longitude': -117.19,
#   'median_house_value': 182400.0,
#   'median_income': 6.4962,
#   'population': 900.0,
#   'total_bedrooms': 340.0,
#   'total_rooms': 2513.0},
#  {'_id': ObjectId('6291e1184c5577003be8985f'),
#   'households': 321.0,
#   'housing_median_age': 28.0,
#   'latitude': 32.8,
#   'longitude': -117.24,
#   'median_house_value': 187500.0,
#   'median_income': 2.1357,
#   'population': 692.0,
#   'total_bedrooms': 331.0,
#   'total_rooms': 1072.0},
#  {'_id': ObjectId('6291e1184c5577003be89860'),
#   'households': 703.0,
#   'housing_median_age': 19.0,
#   'latitude': 34.1,
#   'longitude': -118.13,
#   'median_house_value': 197500.0,
#   'median_income': 2.5663,
#   'population': 1396.0,
#   'total_bedrooms': 756.0,
#   'total_rooms': 2742.0},
#  {'_id': ObjectId('6291e1184c5577003be89861'),
#   'households': 671.0,
#   'housing_median_age': 50.0,
#   'latitude': 37.73,
#   'longitude': -122.42,
#   'median_house_value': 246400.0,
#   'median_income': 2.888,
#   'population': 2261.0,
#   'total_bedrooms': 769.0,
#   'total_rooms': 3426.0},
#  {'_id': ObjectId('6291e1184c5577003be89864'),
#   'households': 391.0,
#   'housing_median_age': 39.0,
#   'latitude': 37.56,
#   'longitude': -122.34,
#   'median_house_value': 500001.0,
#   'median_income': 12.6417,
#   'population': 1139.0,
#   'total_bedrooms': 391.0,
#   'total_rooms': 3562.0},
#  {'_id': ObjectId('6291e1184c5577003be89865'),
#   'households': 484.0,
#   'housing_median_age': 16.0,
#   'latitude': 40.46,
#   'longitude': -122.45,
#   'median_house_value': 105700.0,
#   'median_income': 2.8085,
#   'population': 1413.0,
#   'total_bedrooms': 501.0,
#   'total_rooms': 2734.0},
#  {'_id': ObjectId('6291e1184c5577003be89866'),
#   'households': 593.0,
#   'housing_median_age': 31.0,
#   'latitude': 33.91,
#   'longitude': -118.29,
#   'median_house_value': 151200.0,
#   'median_income': 2.4741,
#   'population': 2231.0,
#   'total_bedrooms': 618.0,
#   'total_rooms': 2025.0},
#  {'_id': ObjectId('6291e1184c5577003be89867'),
#   'households': 640.0,
#   'housing_median_age': 34.0,
#   'latitude': 33.91,
#   'longitude': -118.32,
#   'median_house_value': 181300.0,
#   'median_income': 4.5304,
#   'population': 1920.0,
#   'total_bedrooms': 677.0,
#   'total_rooms': 3041.0},
#  {'_id': ObjectId('6291e1184c5577003be89868'),
#   'households': 472.0,
#   'housing_median_age': 26.0,
#   'latitude': 37.36,
#   'longitude': -122.04,
#   'median_house_value': 403000.0,
#   'median_income': 6.8753,
#   'population': 1241.0,
#   'total_bedrooms': 460.0,
#   'total_rooms': 3298.0},
#  {'_id': ObjectId('6291e1184c5577003be89869'),
#   'households': 1235.0,
#   'housing_median_age': 12.0,
#   'latitude': 34.1,
#   'longitude': -117.39,
#   'median_house_value': 103800.0,
#   'median_income': 2.4492,
#   'population': 4862.0,
#   'total_bedrooms': 1516.0,
#   'total_rooms': 7184.0},
#  {'_id': ObjectId('6291e1184c5577003be8986a'),
#   'households': 543.0,
#   'housing_median_age': 36.0,
#   'latitude': 37.8,
#   'longitude': -122.25,
#   'median_house_value': 116700.0,
#   'median_income': 2.2303,
#   'population': 1645.0,
#   'total_bedrooms': 606.0,
#   'total_rooms': 1678.0},
#  {'_id': ObjectId('6291e1184c5577003be8986b'),
#   'households': 1178.0,
#   'housing_median_age': 22.0,
#   'latitude': 34.1,
#   'longitude': -117.98,
#   'median_house_value': 159700.0,
#   'median_income': 3.7727,
#   'population': 5389.0,
#   'total_bedrooms': 1209.0,
#   'total_rooms': 5661.0},
#  {'_id': ObjectId('6291e1184c5577003be8986e'),
#   'households': 390.0,
#   'housing_median_age': 35.0,
#   'latitude': 37.79,
#   'longitude': -122.2,
#   'median_house_value': 126000.0,
#   'median_income': 2.3036,
#   'population': 1009.0,
#   'total_bedrooms': 459.0,
#   'total_rooms': 1802.0},
#  {'_id': ObjectId('6291e1184c5577003be8986f'),
#   'households': 596.0,
#   'housing_median_age': 23.0,
#   'latitude': 32.75,
#   'longitude': -117.23,
#   'median_house_value': 101800.0,
#   'median_income': 3.1389,
#   'population': 1275.0,
#   'total_bedrooms': 653.0,
#   'total_rooms': 2415.0},
#  {'_id': ObjectId('6291e1184c5577003be89871'),
#   'households': 216.0,
#   'housing_median_age': 35.0,
#   'latitude': 34.03,
#   'longitude': -117.92,
#   'median_house_value': 157300.0,
#   'median_income': 4.1118,
#   'population': 898.0,
#   'total_bedrooms': 233.0,
#   'total_rooms': 1341.0},
#  {'_id': ObjectId('6291e1184c5577003be89873'),
#   'households': 339.0,
#   'housing_median_age': 45.0,
#   'latitude': 32.72,
#   'longitude': -117.14,
#   'median_house_value': 156300.0,
#   'median_income': 1.6156,
#   'population': 840.0,
#   'total_bedrooms': 310.0,
#   'total_rooms': 1140.0},
#  {'_id': ObjectId('6291e1184c5577003be89874'),
#   'households': 349.0,
#   'housing_median_age': 41.0,
#   'latitude': 37.54,
#   'longitude': -122.29,
#   'median_house_value': 282400.0,
#   'median_income': 4.9464,
#   'population': 811.0,
#   'total_bedrooms': 349.0,
#   'total_rooms': 1743.0},
#  {'_id': ObjectId('6291e1184c5577003be89875'),
#   'households': 787.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.94,
#   'longitude': -117.91,
#   'median_house_value': 350500.0,
#   'median_income': 6.3433,
#   'population': 2314.0,
#   'total_bedrooms': 842.0,
#   'total_rooms': 5799.0},
#  {'_id': ObjectId('6291e1184c5577003be89876'),
#   'households': 731.0,
#   'housing_median_age': 8.0,
#   'latitude': 34.27,
#   'longitude': -118.38,
#   'median_house_value': 158300.0,
#   'median_income': 2.8214,
#   'population': 2608.0,
#   'total_bedrooms': 847.0,
#   'total_rooms': 3248.0},
#  {'_id': ObjectId('6291e1184c5577003be89877'),
#   'households': 389.0,
#   'housing_median_age': 24.0,
#   'latitude': 37.6,
#   'longitude': -122.03,
#   'median_house_value': 214700.0,
#   'median_income': 4.5721,
#   'population': 1488.0,
#   'total_bedrooms': 383.0,
#   'total_rooms': 2077.0},
#  {'_id': ObjectId('6291e1184c5577003be89878'),
#   'households': 663.0,
#   'housing_median_age': 16.0,
#   'latitude': 33.15,
#   'longitude': -117.13,
#   'median_house_value': 172600.0,
#   'median_income': 3.1776,
#   'population': 1759.0,
#   'total_bedrooms': 671.0,
#   'total_rooms': 3907.0},
#  {'_id': ObjectId('6291e1184c5577003be89879'),
#   'households': 247.0,
#   'housing_median_age': 42.0,
#   'latitude': 34.0,
#   'longitude': -118.28,
#   'median_house_value': 112500.0,
#   'median_income': 1.2778,
#   'population': 890.0,
#   'total_bedrooms': 284.0,
#   'total_rooms': 855.0},
#  {'_id': ObjectId('6291e1184c5577003be8987a'),
#   'households': 300.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.72,
#   'longitude': -122.45,
#   'median_house_value': 261800.0,
#   'median_income': 4.3036,
#   'population': 890.0,
#   'total_bedrooms': 319.0,
#   'total_rooms': 1729.0},
#  {'_id': ObjectId('6291e1184c5577003be8987c'),
#   'households': 773.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.64,
#   'longitude': -117.7,
#   'median_house_value': 326600.0,
#   'median_income': 8.1926,
#   'population': 2380.0,
#   'total_bedrooms': 773.0,
#   'total_rooms': 5743.0},
#  {'_id': ObjectId('6291e1184c5577003be8987d'),
#   'households': 602.0,
#   'housing_median_age': 36.0,
#   'latitude': 32.79,
#   'longitude': -117.07,
#   'median_house_value': 170800.0,
#   'median_income': 3.9745,
#   'population': 1711.0,
#   'total_bedrooms': 642.0,
#   'total_rooms': 3583.0},
#  {'_id': ObjectId('6291e1184c5577003be8987e'),
#   'households': 662.0,
#   'housing_median_age': 13.0,
#   'latitude': 33.62,
#   'longitude': -117.85,
#   'median_house_value': 500001.0,
#   'median_income': 15.0001,
#   'population': 1865.0,
#   'total_bedrooms': 658.0,
#   'total_rooms': 5192.0},
#  {'_id': ObjectId('6291e1184c5577003be8987f'),
#   'households': 342.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.71,
#   'longitude': -117.76,
#   'median_house_value': 108300.0,
#   'median_income': 3.2229,
#   'population': 470.0,
#   'total_bedrooms': 350.0,
#   'total_rooms': 1010.0},
#  {'_id': ObjectId('6291e1184c5577003be89881'),
#   'households': 680.0,
#   'housing_median_age': 15.0,
#   'latitude': 37.69,
#   'longitude': -120.97,
#   'median_house_value': 114300.0,
#   'median_income': 3.072,
#   'population': 1986.0,
#   'total_bedrooms': 841.0,
#   'total_rooms': 4065.0},
#  {'_id': ObjectId('6291e1184c5577003be89882'),
#   'households': 243.0,
#   'housing_median_age': 12.0,
#   'latitude': 33.64,
#   'longitude': -117.19,
#   'median_house_value': 210700.0,
#   'median_income': 3.235,
#   'population': 757.0,
#   'total_bedrooms': 265.0,
#   'total_rooms': 1481.0},
#  {'_id': ObjectId('6291e1184c5577003be89883'),
#   'households': 534.0,
#   'housing_median_age': 36.0,
#   'latitude': 33.91,
#   'longitude': -118.38,
#   'median_house_value': 289600.0,
#   'median_income': 5.8374,
#   'population': 1463.0,
#   'total_bedrooms': 515.0,
#   'total_rooms': 2904.0},
#  {'_id': ObjectId('6291e1184c5577003be89884'),
#   'households': 314.0,
#   'housing_median_age': 43.0,
#   'latitude': 38.26,
#   'longitude': -121.56,
#   'median_house_value': 136800.0,
#   'median_income': 2.9744,
#   'population': 996.0,
#   'total_bedrooms': 327.0,
#   'total_rooms': 1906.0},
#  {'_id': ObjectId('6291e1184c5577003be89886'),
#   'households': 643.0,
#   'housing_median_age': 24.0,
#   'latitude': 32.8,
#   'longitude': -116.96,
#   'median_house_value': 104200.0,
#   'median_income': 1.8357,
#   'population': 1420.0,
#   'total_bedrooms': 693.0,
#   'total_rooms': 2493.0},
#  {'_id': ObjectId('6291e1184c5577003be89888'),
#   'households': 1061.0,
#   'housing_median_age': 36.0,
#   'latitude': 34.19,
#   'longitude': -119.18,
#   'median_house_value': 179100.0,
#   'median_income': 2.8561,
#   'population': 4818.0,
#   'total_bedrooms': 1081.0,
#   'total_rooms': 4519.0},
#  {'_id': ObjectId('6291e1184c5577003be8988c'),
#   'households': 653.0,
#   'housing_median_age': 42.0,
#   'latitude': 34.17,
#   'longitude': -118.14,
#   'median_house_value': 166800.0,
#   'median_income': 2.7148,
#   'population': 2112.0,
#   'total_bedrooms': 713.0,
#   'total_rooms': 2757.0},
#  {'_id': ObjectId('6291e1184c5577003be8988d'),
#   'households': 551.0,
#   'housing_median_age': 12.0,
#   'latitude': 35.41,
#   'longitude': -119.09,
#   'median_house_value': 130600.0,
#   'median_income': 5.6235,
#   'population': 1754.0,
#   'total_bedrooms': 522.0,
#   'total_rooms': 3449.0},
#  {'_id': ObjectId('6291e1184c5577003be8988e'),
#   'households': 435.0,
#   'housing_median_age': 24.0,
#   'latitude': 33.71,
#   'longitude': -118.02,
#   'median_house_value': 287800.0,
#   'median_income': 5.8623,
#   'population': 1184.0,
#   'total_bedrooms': 443.0,
#   'total_rooms': 2598.0},
#  {'_id': ObjectId('6291e1184c5577003be89890'),
#   'households': 741.0,
#   'housing_median_age': 38.0,
#   'latitude': 34.28,
#   'longitude': -119.29,
#   'median_house_value': 192500.0,
#   'median_income': 2.3147,
#   'population': 1537.0,
#   'total_bedrooms': 748.0,
#   'total_rooms': 2387.0},
#  {'_id': ObjectId('6291e1184c5577003be89891'),
#   'households': 215.0,
#   'housing_median_age': 33.0,
#   'latitude': 37.34,
#   'longitude': -121.84,
#   'median_house_value': 165000.0,
#   'median_income': 4.0929,
#   'population': 938.0,
#   'total_bedrooms': 191.0,
#   'total_rooms': 1019.0},
#  {'_id': ObjectId('6291e1184c5577003be89892'),
#   'households': 314.0,
#   'housing_median_age': 42.0,
#   'latitude': 33.88,
#   'longitude': -117.99,
#   'median_house_value': 161100.0,
#   'median_income': 3.9559,
#   'population': 986.0,
#   'total_bedrooms': 302.0,
#   'total_rooms': 1461.0},
#  {'_id': ObjectId('6291e1184c5577003be89893'),
#   'households': 975.0,
#   'housing_median_age': 3.0,
#   'latitude': 37.55,
#   'longitude': -122.24,
#   'median_house_value': 435900.0,
#   'median_income': 6.7413,
#   'population': 2198.0,
#   'total_bedrooms': 1175.0,
#   'total_rooms': 6164.0},
#  {'_id': ObjectId('6291e1184c5577003be89894'),
#   'households': 389.0,
#   'housing_median_age': 21.0,
#   'latitude': 37.31,
#   'longitude': -121.8,
#   'median_house_value': 232000.0,
#   'median_income': 5.0543,
#   'population': 1789.0,
#   'total_bedrooms': 446.0,
#   'total_rooms': 2630.0},
#  {'_id': ObjectId('6291e1184c5577003be89895'),
#   'households': 1019.0,
#   'housing_median_age': 13.0,
#   'latitude': 34.08,
#   'longitude': -117.43,
#   'median_house_value': 121700.0,
#   'median_income': 2.1189,
#   'population': 2475.0,
#   'total_bedrooms': 1187.0,
#   'total_rooms': 4563.0},
#  {'_id': ObjectId('6291e1184c5577003be89896'),
#   'households': 217.0,
#   'housing_median_age': 29.0,
#   'latitude': 34.02,
#   'longitude': -118.28,
#   'median_house_value': 500001.0,
#   'median_income': 0.4999,
#   'population': 2690.0,
#   'total_bedrooms': 229.0,
#   'total_rooms': 515.0},
#  {'_id': ObjectId('6291e1184c5577003be89897'),
#   'households': 485.0,
#   'housing_median_age': 31.0,
#   'latitude': 33.06,
#   'longitude': -117.3,
#   'median_house_value': 290000.0,
#   'median_income': 4.027,
#   'population': 1049.0,
#   'total_bedrooms': 520.0,
#   'total_rooms': 2128.0},
#  {'_id': ObjectId('6291e1184c5577003be89898'),
#   'households': 218.0,
#   'housing_median_age': 18.0,
#   'latitude': 34.04,
#   'longitude': -118.2,
#   'median_house_value': 135400.0,
#   'median_income': 1.0333,
#   'population': 547.0,
#   'total_bedrooms': 227.0,
#   'total_rooms': 796.0},
#  {'_id': ObjectId('6291e1184c5577003be89899'),
#   'households': 456.0,
#   'housing_median_age': 30.0,
#   'latitude': 34.11,
#   'longitude': -117.63,
#   'median_house_value': 165600.0,
#   'median_income': 4.2969,
#   'population': 1404.0,
#   'total_bedrooms': 428.0,
#   'total_rooms': 2674.0},
#  {'_id': ObjectId('6291e1184c5577003be8989a'),
#   'households': 261.0,
#   'housing_median_age': 37.0,
#   'latitude': 37.33,
#   'longitude': -121.94,
#   'median_house_value': 250000.0,
#   'median_income': 2.1902,
#   'population': 576.0,
#   'total_bedrooms': 269.0,
#   'total_rooms': 818.0},
#  {'_id': ObjectId('6291e1184c5577003be8989b'),
#   'households': 158.0,
#   'housing_median_age': 5.0,
#   'latitude': 33.93,
#   'longitude': -118.07,
#   'median_house_value': 171900.0,
#   'median_income': 4.125,
#   'population': 1453.0,
#   'total_bedrooms': 187.0,
#   'total_rooms': 906.0},
#  {'_id': ObjectId('6291e1184c5577003be8989c'),
#   'households': 532.0,
#   'housing_median_age': 30.0,
#   'latitude': 32.83,
#   'longitude': -117.19,
#   'median_house_value': 173300.0,
#   'median_income': 4.3317,
#   'population': 1601.0,
#   'total_bedrooms': 555.0,
#   'total_rooms': 3225.0},
#  {'_id': ObjectId('6291e1184c5577003be8989d'),
#   'households': 297.0,
#   'housing_median_age': 42.0,
#   'latitude': 33.89,
#   'longitude': -118.21,
#   'median_house_value': 120700.0,
#   'median_income': 2.2125,
#   'population': 1104.0,
#   'total_bedrooms': 370.0,
#   'total_rooms': 1739.0},
#  {'_id': ObjectId('6291e1184c5577003be8989e'),
#   'households': 247.0,
#   'housing_median_age': 39.0,
#   'latitude': 34.19,
#   'longitude': -118.41,
#   'median_house_value': 200000.0,
#   'median_income': 4.1429,
#   'population': 612.0,
#   'total_bedrooms': 242.0,
#   'total_rooms': 1169.0},
#  {'_id': ObjectId('6291e1184c5577003be8989f'),
#   'households': 368.0,
#   'housing_median_age': 29.0,
#   'latitude': 32.8,
#   'longitude': -117.0,
#   'median_house_value': 144100.0,
#   'median_income': 3.0189,
#   'population': 912.0,
#   'total_bedrooms': 398.0,
#   'total_rooms': 2045.0},
#  {'_id': ObjectId('6291e1184c5577003be898a0'),
#   'households': 497.0,
#   'housing_median_age': 11.0,
#   'latitude': 32.86,
#   'longitude': -116.92,
#   'median_house_value': 127000.0,
#   'median_income': 2.3693,
#   'population': 1472.0,
#   'total_bedrooms': 518.0,
#   'total_rooms': 2204.0},
#  {'_id': ObjectId('6291e1184c5577003be898a1'),
#   'households': 407.0,
#   'housing_median_age': 22.0,
#   'latitude': 38.95,
#   'longitude': -121.04,
#   'median_house_value': 153200.0,
#   'median_income': 2.75,
#   'population': 1009.0,
#   'total_bedrooms': 445.0,
#   'total_rooms': 1931.0},
#  {'_id': ObjectId('6291e1184c5577003be898a2'),
#   'households': 287.0,
#   'housing_median_age': 38.0,
#   'latitude': 37.45,
#   'longitude': -122.12,
#   'median_house_value': 155700.0,
#   'median_income': 2.0096,
#   'population': 955.0,
#   'total_bedrooms': 314.0,
#   'total_rooms': 1276.0},
#  {'_id': ObjectId('6291e1184c5577003be898a3'),
#   'households': 335.0,
#   'housing_median_age': 28.0,
#   'latitude': 36.54,
#   'longitude': -119.48,
#   'median_house_value': 108900.0,
#   'median_income': 4.2222,
#   'population': 1011.0,
#   'total_bedrooms': 363.0,
#   'total_rooms': 2112.0},
#  {'_id': ObjectId('6291e1184c5577003be898a4'),
#   'households': 578.0,
#   'housing_median_age': 25.0,
#   'latitude': 37.68,
#   'longitude': -121.02,
#   'median_house_value': 114500.0,
#   'median_income': 3.996,
#   'population': 1834.0,
#   'total_bedrooms': 588.0,
#   'total_rooms': 3262.0},
#  {'_id': ObjectId('6291e1184c5577003be898a7'),
#   'households': 1735.0,
#   'housing_median_age': 21.0,
#   'latitude': 37.97,
#   'longitude': -122.04,
#   'median_house_value': 112500.0,
#   'median_income': 2.5841,
#   'population': 3621.0,
#   'total_bedrooms': 1839.0,
#   'total_rooms': 6445.0},
# ...
#   'latitude': 38.62,
#   'longitude': -121.37,
#   'median_house_value': 166100.0,
#   'median_income': 1.6678,
#   'population': 697.0,
#   'total_bedrooms': 380.0,
#   'total_rooms': 1743.0},
#  {'_id': ObjectId('6291e1184c5577003be89c59'),
#   'households': 418.0,
#   'housing_median_age': 43.0,
#   'latitude': 33.82,
#   'longitude': -118.18,
#   'median_house_value': 216700.0,
#   'median_income': 3.5,
#   'population': 1042.0,
#   'total_bedrooms': 469.0,
#   'total_rooms': 2210.0},
#  {'_id': ObjectId('6291e1184c5577003be89c5a'),
#   'households': 456.0,
#   'housing_median_age': 33.0,
#   'latitude': 33.77,
#   'longitude': -118.02,
#   'median_house_value': 211500.0,
#   'median_income': 5.0091,
#   'population': 1520.0,
#   'total_bedrooms': 436.0,
#   'total_rooms': 2683.0},
#  {'_id': ObjectId('6291e1184c5577003be89c5b'),
#   'households': 211.0,
#   'housing_median_age': 21.0,
#   'latitude': 34.47,
#   'longitude': -120.05,
#   'median_house_value': 425000.0,
#   'median_income': 3.8056,
#   'population': 746.0,
#   'total_bedrooms': 248.0,
#   'total_rooms': 1241.0},
#  {'_id': ObjectId('6291e1184c5577003be89c5e'),
#   'households': 292.0,
#   'housing_median_age': 7.0,
#   'latitude': 34.5,
#   'longitude': -117.27,
#   'median_house_value': 194100.0,
#   'median_income': 6.0296,
#   'population': 878.0,
#   'total_bedrooms': 342.0,
#   'total_rooms': 2045.0},
#  {'_id': ObjectId('6291e1184c5577003be89c5f'),
#   'households': 666.0,
#   'housing_median_age': 23.0,
#   'latitude': 36.99,
#   'longitude': -121.96,
#   'median_house_value': 238000.0,
#   'median_income': 2.7375,
#   'population': 1423.0,
#   'total_bedrooms': 748.0,
#   'total_rooms': 3209.0},
#  {'_id': ObjectId('6291e1184c5577003be89c60'),
#   'households': 239.0,
#   'housing_median_age': 45.0,
#   'latitude': 34.04,
#   'longitude': -118.19,
#   'median_house_value': 134900.0,
#   'median_income': 2.1806,
#   'population': 1194.0,
#   'total_bedrooms': 234.0,
#   'total_rooms': 963.0},
#  {'_id': ObjectId('6291e1184c5577003be89c62'),
#   'households': 482.0,
#   'housing_median_age': 29.0,
#   'latitude': 33.79,
#   'longitude': -117.96,
#   'median_house_value': 214500.0,
#   'median_income': 2.0677,
#   'population': 1170.0,
#   'total_bedrooms': 501.0,
#   'total_rooms': 1813.0},
#  {'_id': ObjectId('6291e1184c5577003be89c63'),
#   'households': 958.0,
#   'housing_median_age': 25.0,
#   'latitude': 34.17,
#   'longitude': -118.44,
#   'median_house_value': 286700.0,
#   'median_income': 3.8081,
#   'population': 1941.0,
#   'total_bedrooms': 1134.0,
#   'total_rooms': 4966.0},
#  {'_id': ObjectId('6291e1184c5577003be89c64'),
#   'households': 262.0,
#   'housing_median_age': 35.0,
#   'latitude': 37.52,
#   'longitude': -122.31,
#   'median_house_value': 457200.0,
#   'median_income': 6.8336,
#   'population': 659.0,
#   'total_bedrooms': 262.0,
#   'total_rooms': 1817.0},
#  {'_id': ObjectId('6291e1184c5577003be89c65'),
#   'households': 436.0,
#   'housing_median_age': 24.0,
#   'latitude': 33.92,
#   'longitude': -117.97,
#   'median_house_value': 251400.0,
#   'median_income': 3.0,
#   'population': 900.0,
#   'total_bedrooms': 416.0,
#   'total_rooms': 2017.0},
#  {'_id': ObjectId('6291e1184c5577003be89c66'),
#   'households': 481.0,
#   'housing_median_age': 20.0,
#   'latitude': 34.05,
#   'longitude': -117.71,
#   'median_house_value': 130500.0,
#   'median_income': 2.5735,
#   'population': 1545.0,
#   'total_bedrooms': 444.0,
#   'total_rooms': 2281.0},
#  {'_id': ObjectId('6291e1184c5577003be89c67'),
#   'households': 789.0,
#   'housing_median_age': 26.0,
#   'latitude': 34.02,
#   'longitude': -118.42,
#   'median_house_value': 301900.0,
#   'median_income': 3.4269,
#   'population': 1745.0,
#   'total_bedrooms': 842.0,
#   'total_rooms': 2664.0},
#  {'_id': ObjectId('6291e1184c5577003be89c69'),
#   'households': 352.0,
#   'housing_median_age': 29.0,
#   'latitude': 38.51,
#   'longitude': -121.35,
#   'median_house_value': 157700.0,
#   'median_income': 4.2206,
#   'population': 1054.0,
#   'total_bedrooms': 391.0,
#   'total_rooms': 2337.0},
#  {'_id': ObjectId('6291e1184c5577003be89c6a'),
#   'households': 433.0,
#   'housing_median_age': 15.0,
#   'latitude': 38.55,
#   'longitude': -120.25,
#   'median_house_value': 111700.0,
#   'median_income': 3.0125,
#   'population': 1103.0,
#   'total_bedrooms': 891.0,
#   'total_rooms': 4403.0},
#  {'_id': ObjectId('6291e1184c5577003be89c6b'),
#   'households': 969.0,
#   'housing_median_age': 21.0,
#   'latitude': 34.02,
#   'longitude': -118.02,
#   'median_house_value': 302400.0,
#   'median_income': 5.2405,
#   'population': 2647.0,
#   'total_bedrooms': 986.0,
#   'total_rooms': 5992.0},
#  {'_id': ObjectId('6291e1184c5577003be89c6c'),
#   'households': 1165.0,
#   'housing_median_age': 15.0,
#   'latitude': 35.26,
#   'longitude': -120.66,
#   'median_house_value': 226200.0,
#   'median_income': 2.2656,
#   'population': 2383.0,
#   'total_bedrooms': 1319.0,
#   'total_rooms': 5540.0},
#  {'_id': ObjectId('6291e1184c5577003be89c6f'),
#   'households': 454.0,
#   'housing_median_age': 47.0,
#   'latitude': 37.78,
#   'longitude': -122.51,
#   'median_house_value': 342200.0,
#   'median_income': 4.0353,
#   'population': 1201.0,
#   'total_bedrooms': 494.0,
#   'total_rooms': 2496.0},
#  {'_id': ObjectId('6291e1184c5577003be89c70'),
#   'households': 363.0,
#   'housing_median_age': 22.0,
#   'latitude': 34.65,
#   'longitude': -120.46,
#   'median_house_value': 117500.0,
#   'median_income': 1.6488,
#   'population': 1272.0,
#   'total_bedrooms': 358.0,
#   'total_rooms': 1298.0},
#  {'_id': ObjectId('6291e1184c5577003be89c71'),
#   'households': 523.0,
#   'housing_median_age': 25.0,
#   'latitude': 33.93,
#   'longitude': -117.93,
#   'median_house_value': 184400.0,
#   'median_income': 3.7933,
#   'population': 1702.0,
#   'total_bedrooms': 534.0,
#   'total_rooms': 2431.0},
#  {'_id': ObjectId('6291e1184c5577003be89c72'),
#   'households': 317.0,
#   'housing_median_age': 49.0,
#   'latitude': 33.97,
#   'longitude': -118.21,
#   'median_house_value': 170600.0,
#   'median_income': 3.9408,
#   'population': 1268.0,
#   'total_bedrooms': 313.0,
#   'total_rooms': 1409.0},
#  {'_id': ObjectId('6291e1184c5577003be89c73'),
#   'households': 225.0,
#   'housing_median_age': 25.0,
#   'latitude': 34.62,
#   'longitude': -120.18,
#   'median_house_value': 226400.0,
#   'median_income': 3.1912,
#   'population': 671.0,
#   'total_bedrooms': 219.0,
#   'total_rooms': 1337.0},
#  {'_id': ObjectId('6291e1184c5577003be89c74'),
#   'households': 600.0,
#   'housing_median_age': 18.0,
#   'latitude': 37.43,
#   'longitude': -122.14,
#   'median_house_value': 378600.0,
#   'median_income': 4.0686,
#   'population': 1144.0,
#   'total_bedrooms': 563.0,
#   'total_rooms': 2060.0},
#  {'_id': ObjectId('6291e1184c5577003be89c76'),
#   'households': 774.0,
#   'housing_median_age': 25.0,
#   'latitude': 33.84,
#   'longitude': -117.94,
#   'median_house_value': 135400.0,
#   'median_income': 3.1884,
#   'population': 2166.0,
#   'total_bedrooms': 831.0,
#   'total_rooms': 4016.0},
#  {'_id': ObjectId('6291e1184c5577003be89c77'),
#   'households': 1131.0,
#   'housing_median_age': 4.0,
#   'latitude': 38.48,
#   'longitude': -122.75,
#   'median_house_value': 197400.0,
#   'median_income': 4.5417,
#   'population': 2958.0,
#   'total_bedrooms': 1112.0,
#   'total_rooms': 6487.0},
#  {'_id': ObjectId('6291e1184c5577003be89c78'),
#   'households': 694.0,
#   'housing_median_age': 16.0,
#   'latitude': 37.15,
#   'longitude': -121.61,
#   'median_house_value': 416300.0,
#   'median_income': 7.8601,
#   'population': 2051.0,
#   'total_bedrooms': 729.0,
#   'total_rooms': 5498.0},
#  {'_id': ObjectId('6291e1184c5577003be89c79'),
#   'households': 411.0,
#   'housing_median_age': 5.0,
#   'latitude': 40.6,
#   'longitude': -122.42,
#   'median_house_value': 122900.0,
#   'median_income': 3.4464,
#   'population': 1275.0,
#   'total_bedrooms': 433.0,
#   'total_rooms': 2614.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7a'),
#   'households': 579.0,
#   'housing_median_age': 14.0,
#   'latitude': 34.95,
#   'longitude': -119.16,
#   'median_house_value': 148200.0,
#   'median_income': 3.0882,
#   'population': 1581.0,
#   'total_bedrooms': 787.0,
#   'total_rooms': 4054.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7b'),
#   'households': 915.0,
#   'housing_median_age': 9.0,
#   'latitude': 34.24,
#   'longitude': -118.63,
#   'median_house_value': 277200.0,
#   'median_income': 4.8333,
#   'population': 1884.0,
#   'total_bedrooms': 924.0,
#   'total_rooms': 4759.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7c'),
#   'households': 802.0,
#   'housing_median_age': 34.0,
#   'latitude': 36.98,
#   'longitude': -121.95,
#   'median_house_value': 261200.0,
#   'median_income': 3.1546,
#   'population': 1622.0,
#   'total_bedrooms': 958.0,
#   'total_rooms': 3745.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7d'),
#   'households': 205.0,
#   'housing_median_age': 43.0,
#   'latitude': 32.79,
#   'longitude': -117.25,
#   'median_house_value': 328600.0,
#   'median_income': 1.8365,
#   'population': 458.0,
#   'total_bedrooms': 240.0,
#   'total_rooms': 906.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7e'),
#   'households': 973.0,
#   'housing_median_age': 15.0,
#   'latitude': 34.22,
#   'longitude': -119.18,
#   'median_house_value': 198700.0,
#   'median_income': 3.9063,
#   'population': 2549.0,
#   'total_bedrooms': 1008.0,
#   'total_rooms': 4615.0},
#  {'_id': ObjectId('6291e1184c5577003be89c7f'),
#   'households': 747.0,
#   'housing_median_age': 34.0,
#   'latitude': 32.82,
#   'longitude': -117.26,
#   'median_house_value': 500001.0,
#   'median_income': 8.496,
#   'population': 1817.0,
#   'total_bedrooms': 785.0,
#   'total_rooms': 5846.0},
#  {'_id': ObjectId('6291e1184c5577003be89c80'),
#   'households': 309.0,
#   'housing_median_age': 25.0,
#   'latitude': 32.79,
#   'longitude': -117.07,
#   'median_house_value': 277600.0,
#   'median_income': 7.8336,
#   'population': 911.0,
#   'total_bedrooms': 314.0,
#   'total_rooms': 2489.0},
#  {'_id': ObjectId('6291e1184c5577003be89c82'),
#   'households': 89.0,
#   'housing_median_age': 52.0,
#   'latitude': 34.13,
#   'longitude': -118.25,
#   'median_house_value': 243800.0,
#   'median_income': 2.125,
#   'population': 229.0,
#   'total_bedrooms': 88.0,
#   'total_rooms': 322.0},
#  {'_id': ObjectId('6291e1184c5577003be89c83'),
#   'households': 375.0,
#   'housing_median_age': 18.0,
#   'latitude': 34.26,
#   'longitude': -117.28,
#   'median_house_value': 133600.0,
#   'median_income': 3.3672,
#   'population': 1086.0,
#   'total_bedrooms': 689.0,
#   'total_rooms': 3895.0},
#  {'_id': ObjectId('6291e1184c5577003be89c84'),
#   'households': 723.0,
#   'housing_median_age': 32.0,
#   'latitude': 38.11,
#   'longitude': -122.57,
#   'median_house_value': 228600.0,
#   'median_income': 3.4705,
#   'population': 1706.0,
#   'total_bedrooms': 748.0,
#   'total_rooms': 3521.0},
#  {'_id': ObjectId('6291e1184c5577003be89c85'),
#   'households': 208.0,
#   'housing_median_age': 52.0,
#   'latitude': 37.79,
#   'longitude': -122.45,
#   'median_house_value': 500001.0,
#   'median_income': 10.7097,
#   'population': 495.0,
#   'total_bedrooms': 215.0,
#   'total_rooms': 1457.0},
#  {'_id': ObjectId('6291e1184c5577003be89c86'),
#   'households': 303.0,
#   'housing_median_age': 15.0,
#   'latitude': 33.71,
#   'longitude': -117.77,
#   'median_house_value': 337100.0,
#   'median_income': 7.3141,
#   'population': 1060.0,
#   'total_bedrooms': 295.0,
#   'total_rooms': 2102.0},
#  {'_id': ObjectId('6291e1184c5577003be89c88'),
#   'households': 445.0,
#   'housing_median_age': 37.0,
#   'latitude': 33.93,
#   'longitude': -118.32,
#   'median_house_value': 172100.0,
#   'median_income': 4.25,
#   'population': 1327.0,
#   'total_bedrooms': 462.0,
#   'total_rooms': 2379.0},
#  {'_id': ObjectId('6291e1184c5577003be89c89'),
#   'households': 596.0,
#   'housing_median_age': 28.0,
#   'latitude': 33.79,
#   'longitude': -118.22,
#   'median_house_value': 137500.0,
#   'median_income': 2.3,
#   'population': 2537.0,
#   'total_bedrooms': 629.0,
#   'total_rooms': 3008.0},
#  {'_id': ObjectId('6291e1184c5577003be89c8a'),
#   'households': 163.0,
#   'housing_median_age': 17.0,
#   'latitude': 38.48,
#   'longitude': -122.65,
#   'median_house_value': 231800.0,
#   'median_income': 5.5061,
#   'population': 473.0,
#   'total_bedrooms': 164.0,
#   'total_rooms': 1090.0},
#  {'_id': ObjectId('6291e1184c5577003be89c8c'),
#   'households': 543.0,
#   'housing_median_age': 26.0,
#   'latitude': 34.09,
#   'longitude': -117.86,
#   'median_house_value': 239100.0,
#   'median_income': 6.1498,
#   'population': 1664.0,
#   'total_bedrooms': 542.0,
#   'total_rooms': 3408.0},
#  {'_id': ObjectId('6291e1184c5577003be89c8d'),
#   'households': 986.0,
#   'housing_median_age': 16.0,
#   'latitude': 37.86,
#   'longitude': -122.06,
#   'median_house_value': 252400.0,
#   'median_income': 4.4551,
#   'population': 1512.0,
#   'total_bedrooms': 1014.0,
#   'total_rooms': 5187.0},
#  {'_id': ObjectId('6291e1184c5577003be89c90'),
#   'households': 30.0,
#   'housing_median_age': 42.0,
#   'latitude': 38.03,
#   'longitude': -122.14,
#   'median_house_value': 225000.0,
#   'median_income': 2.5795,
#   'population': 54.0,
#   'total_bedrooms': 34.0,
#   'total_rooms': 118.0},
#  {'_id': ObjectId('6291e1184c5577003be89c91'),
#   'households': 975.0,
#   'housing_median_age': 18.0,
#   'latitude': 36.8,
#   'longitude': -121.64,
#   'median_house_value': 255200.0,
#   'median_income': 4.5812,
#   'population': 2975.0,
#   'total_bedrooms': 1000.0,
#   'total_rooms': 5915.0},
#  {'_id': ObjectId('6291e1184c5577003be89c92'),
#   'households': 555.0,
#   'housing_median_age': 11.0,
#   'latitude': 38.01,
#   'longitude': -122.24,
#   'median_house_value': 269400.0,
#   'median_income': 5.7862,
#   'population': 1949.0,
#   'total_bedrooms': 565.0,
#   'total_rooms': 3751.0},
#  {'_id': ObjectId('6291e1184c5577003be89c93'),
#   'households': 151.0,
#   'housing_median_age': 19.0,
#   'latitude': 34.31,
#   'longitude': -116.86,
#   'median_house_value': 133000.0,
#   'median_income': 4.0556,
#   'population': 382.0,
#   'total_bedrooms': 328.0,
#   'total_rooms': 1649.0},
#  {'_id': ObjectId('6291e1184c5577003be89c94'),
#   'households': 250.0,
#   'housing_median_age': 21.0,
#   'latitude': 37.88,
#   'longitude': -122.71,
#   'median_house_value': 495800.0,
#   'median_income': 4.3125,
#   'population': 599.0,
#   'total_bedrooms': 552.0,
#   'total_rooms': 2845.0},
#  {'_id': ObjectId('6291e1184c5577003be89c95'),
#   'households': 172.0,
#   'housing_median_age': 8.0,
#   'latitude': 32.56,
#   'longitude': -117.09,
#   'median_house_value': 151500.0,
#   'median_income': 4.8984,
#   'population': 626.0,
#   'total_bedrooms': 156.0,
#   'total_rooms': 864.0},
#  {'_id': ObjectId('6291e1184c5577003be89c96'),
#   'households': 487.0,
#   'housing_median_age': 35.0,
#   'latitude': 37.47,
#   'longitude': -122.25,
#   'median_house_value': 383200.0,
#   'median_income': 5.9062,
#   'population': 1313.0,
#   'total_bedrooms': 515.0,
#   'total_rooms': 3183.0},
#  {'_id': ObjectId('6291e1184c5577003be89c97'),
#   'households': 892.0,
#   'housing_median_age': 20.0,
#   'latitude': 33.77,
#   'longitude': -118.12,
#   'median_house_value': 463500.0,
#   'median_income': 6.0362,
#   'population': 1941.0,
#   'total_bedrooms': 954.0,
#   'total_rooms': 4534.0},
#  {'_id': ObjectId('6291e1184c5577003be89c98'),
#   'households': 546.0,
#   'housing_median_age': 17.0,
#   'latitude': 37.67,
#   'longitude': -120.96,
#   'median_house_value': 114300.0,
#   'median_income': 2.9219,
#   'population': 1558.0,
#   'total_bedrooms': 511.0,
#   'total_rooms': 2434.0},
#  {'_id': ObjectId('6291e1184c5577003be89c9a'),
#   'households': 358.0,
#   'housing_median_age': 52.0,
#   'latitude': 33.96,
#   'longitude': -117.39,
#   'median_house_value': 129300.0,
#   'median_income': 3.2917,
#   'population': 948.0,
#   'total_bedrooms': 345.0,
#   'total_rooms': 1992.0},
#  {'_id': ObjectId('6291e1184c5577003be89c9c'),
#   'households': 783.0,
#   'housing_median_age': 19.0,
#   'latitude': 32.64,
#   'longitude': -117.09,
#   'median_house_value': 131300.0,
#   'median_income': 1.62,
#   'population': 1205.0,
#   'total_bedrooms': 791.0,
#   'total_rooms': 2571.0},
#  {'_id': ObjectId('6291e1184c5577003be89c9d'),
#   'households': 1546.0,
#   'housing_median_age': 15.0,
#   'latitude': 37.93,
#   'longitude': -122.05,
#   'median_house_value': 184900.0,
#   'median_income': 4.45,
#   'population': 2957.0,
#   'total_bedrooms': 1603.0,
#   'total_rooms': 7803.0},
#  {'_id': ObjectId('6291e1184c5577003be89c9e'),
#   'households': 266.0,
#   'housing_median_age': 26.0,
#   'latitude': 34.87,
#   'longitude': -120.43,
#   'median_house_value': 157700.0,
#   'median_income': 3.9871,
#   'population': 799.0,
#   'total_bedrooms': 272.0,
#   'total_rooms': 1699.0},
#  ...]

# %%
query_df = pd.DataFrame(list ( collection.find( { 'median_house_value': { '$gt': 100000 } } )))
query_df.to_csv('/content/sample_data/query.csv')
